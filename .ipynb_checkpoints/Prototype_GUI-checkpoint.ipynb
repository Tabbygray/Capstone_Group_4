# %%
# Out:
# None {1: None, 'Browse': None, 3: None, 4: None, 5: None, 6: None, 7: None}

# %%
import PySimpleGUI as sg

sg.theme("lightGrey2")  # No gray windows please!
# 컴포넌트 정의
# STEP 1 define the layout


left_column = [
    [sg.Image(r"sample_img.png", size=(200, 200))],
    [sg.Text("리셉터 파일을 업로드" , size=(30, 1),justification='center')],
    [sg.Input("파일 경로 입력...", size=(25, 1)), sg.FileBrowse(button_text='찾아보기...')],
    [sg.Text("_" * 35)],
    [sg.Text("추천되는 파라미터" , size=(30, 1),justification='center')],
    [sg.Text("exhaustiveness : 8 \n Grid 8 8 8 ",size=(30, 3),justification='center')],
]


right_column = [
    [sg.Text("col Row 1")],
    [
        sg.Frame(
            "My Frame Title",
            [
                [sg.T("리간드 파일 선택")],
                [
                    sg.Column(
                        [
                            [sg.Image(r"folder_icon.png", size=(60, 60))],
                            [sg.Text("리셉터 폴더 선택")],
                        ],
                        element_justification="center",
                    ),
                    sg.Column(
                        [
                            [sg.Image(r"db_icon.png", size=(60, 60))],
                            [sg.Text("온라인 DB 사용")],
                        ],
                        element_justification="center",
                    ),
                ],
                [sg.Input("폴더 경로 입력...", size=(25, 1)), sg.FolderBrowse(button_text='찾아보기...')],
            ],
        )
    ],
    [
        sg.Table(
            [["Dapagliflozin (1)", "대기중", "--:--:--", "--", "--"], [4, 5, 6, 7, 8]],
            ["리간드 이름", "Docking 수행", "Docking 수행 시간", "결과 평가", "사용한 파라미터"],
            num_rows=2,
            justification="center",
        )
    ],
]


layout = [
    [sg.Column(left_column, expand_y = True), sg.VerticalSeparator(pad=None), sg.Column(right_column,expand_y = True)],
    [sg.Button("Button"), sg.Button("Exit")],
]

column = [[sg.Column(layout)]]
# STEP 2 - create the window
window = sg.Window("My new window", column, grab_anywhere=True)

# STEP3 - the event loop
while True:
    (
        event,
        values,
    ) = window.read()  # Read the event that happened and the values dictionary
    print(event, values)
    if event in (
        None,
        "Exit",
    ):  # If user closeddow with X or if user clicked "Exit" button then exit
        break
    if event == "Button":
        print("You pressed the button")
window.close()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\anaconda3\envs\PT37\lib\site-packages\PySimpleGUI\PySimpleGUI.py", line 15855, in PackFormIntoFrame
#     photo = tk.PhotoImage(file=element.Filename)
#   File "D:\anaconda3\envs\PT37\lib\tkinter\__init__.py", line 3545, in __init__
#     Image.__init__(self, 'photo', name, cnf, master, **kw)
#   File "D:\anaconda3\envs\PT37\lib\tkinter\__init__.py", line 3501, in __init__
#     self.tk.call(('image', 'create', imgtype, name,) + options)
# _tkinter.TclError: couldn't open "\sample_img.png": no such file or directory
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\envs\PT37\lib\site-packages\IPython\core\interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\jundo\AppData\Local\Temp\ipykernel_17304\3441995416.py", line 70, in <module>
#     ) = window.read()  # Read the event that happened and the values dictionary
#   File "D:\anaconda3\envs\PT37\lib\site-packages\PySimpleGUI\PySimpleGUI.py", line 10075, in read
#     results = self._read(timeout=timeout, timeout_key=timeout_key)
#   File "D:\anaconda3\envs\PT37\lib\site-packages\PySimpleGUI\PySimpleGUI.py", line 10146, in _read
#     self._Show()
#   File "D:\anaconda3\envs\PT37\lib\site-packages\PySimpleGUI\PySimpleGUI.py", line 9886, in _Show
#     StartupTK(self)
#   File "D:\anaconda3\envs\PT37\lib\site-packages\PySimpleGUI\PySimpleGUI.py", line 16866, in StartupTK
#     _convert_window_to_tk(window)
#   File "D:\anaconda3\envs\PT37\lib\site-packages\PySimpleGUI\PySimpleGUI.py", line 16753, in _convert_window_to_tk
#     PackFormIntoFrame(window, master, window)
#   File "D:\anaconda3\envs\PT37\lib\site-packages\PySimpleGUI\PySimpleGUI.py", line 14846, in PackFormIntoFrame
#     PackFormIntoFrame(element, element.TKColFrame, toplevel_form)
#   File "D:\anaconda3\envs\PT37\lib\site-packages\PySimpleGUI\PySimpleGUI.py", line 14846, in PackFormIntoFrame
#     PackFormIntoFrame(element, element.TKColFrame, toplevel_form)
#   File "D:\anaconda3\envs\PT37\lib\site-packages\PySimpleGUI\PySimpleGUI.py", line 15869, in PackFormIntoFrame
#     'The error occuring is:', e)
#   File "D:\anaconda3\envs\PT37\lib\site-packages\PySimpleGUI\PySimpleGUI.py", line 20931, in _error_popup_with_traceback
#     _error_popup_with_code(title, filename, line_num, error_message, *args)
#   File "D:\anaconda3\envs\PT37\lib\site-packages\PySimpleGUI\PySimpleGUI.py", line 20956, in _error_popup_with_code
#     sys.exit()
# SystemExit
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\envs\PT37\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "D:\anaconda3\envs\PT37\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "D:\anaconda3\envs\PT37\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "D:\anaconda3\envs\PT37\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
# AttributeError: 'tuple' object has no attribute 'tb_frame'
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# D:\anaconda3\envs\PT37\lib\site-packages\PySimpleGUI\PySimpleGUI.py in PackFormIntoFrame(form, containing_frame, toplevel_form)
#   15854                     if element.Filename is not None:
# > 15855                         photo = tk.PhotoImage(file=element.Filename)
#   15856                     elif element.Data is not None:
#
# D:\anaconda3\envs\PT37\lib\tkinter\__init__.py in __init__(self, name, cnf, master, **kw)
#    3544         width."""
# -> 3545         Image.__init__(self, 'photo', name, cnf, master, **kw)
#    3546     def blank(self):
#
# D:\anaconda3\envs\PT37\lib\tkinter\__init__.py in __init__(self, imgtype, name, cnf, master, **kw)
#    3500             options = options + ('-'+k, v)
# -> 3501         self.tk.call(('image', 'create', imgtype, name,) + options)
#    3502         self.name = name
#
# TclError: couldn't open "\sample_img.png": no such file or directory
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~\AppData\Local\Temp\ipykernel_17304\3441995416.py in <module>
#      69         values,
# ---> 70     ) = window.read()  # Read the event that happened and the values dictionary
#      71     print(event, values)
#
# D:\anaconda3\envs\PT37\lib\site-packages\PySimpleGUI\PySimpleGUI.py in read(self, timeout, timeout_key, close)
#   10074             Window._root_running_mainloop = self.TKroot
# > 10075             results = self._read(timeout=timeout, timeout_key=timeout_key)
#   10076             if results is not None:
#
# D:\anaconda3\envs\PT37\lib\site-packages\PySimpleGUI\PySimpleGUI.py in _read(self, timeout, timeout_key)
#   10145         if not self.Shown:
# > 10146             self._Show()
#   10147         else:
#
# D:\anaconda3\envs\PT37\lib\site-packages\PySimpleGUI\PySimpleGUI.py in _Show(self, non_blocking)
#    9885         # -=-=-=-=-=-=-=-=- RUN the GUI -=-=-=-=-=-=-=-=- ##
# -> 9886         StartupTK(self)
#    9887         # If a button or keyboard event happened but no results have been built, build the results
#
# D:\anaconda3\envs\PT37\lib\site-packages\PySimpleGUI\PySimpleGUI.py in StartupTK(window)
#   16865     # root.bind('<Destroy>', MyFlexForm.DestroyedCallback())
# > 16866     _convert_window_to_tk(window)
#   16867
#
# D:\anaconda3\envs\PT37\lib\site-packages\PySimpleGUI\PySimpleGUI.py in _convert_window_to_tk(window)
#   16752
# > 16753     PackFormIntoFrame(window, master, window)
#   16754
#
# D:\anaconda3\envs\PT37\lib\site-packages\PySimpleGUI\PySimpleGUI.py in PackFormIntoFrame(form, containing_frame, toplevel_form)
#   14845                         element.Widget = element.TKColFrame = tk.Frame(tk_row_frame)
# > 14846                         PackFormIntoFrame(element, element.TKColFrame, toplevel_form)
#   14847                         if element.BackgroundColor not in (None, COLOR_SYSTEM_DEFAULT):
#
# D:\anaconda3\envs\PT37\lib\site-packages\PySimpleGUI\PySimpleGUI.py in PackFormIntoFrame(form, containing_frame, toplevel_form)
#   14845                         element.Widget = element.TKColFrame = tk.Frame(tk_row_frame)
# > 14846                         PackFormIntoFrame(element, element.TKColFrame, toplevel_form)
#   14847                         if element.BackgroundColor not in (None, COLOR_SYSTEM_DEFAULT):
#
# D:\anaconda3\envs\PT37\lib\site-packages\PySimpleGUI\PySimpleGUI.py in PackFormIntoFrame(form, containing_frame, toplevel_form)
#   15868                                                 'Look in this Window\'s layout for an Image element that has a key of {}'.format(element.Key),
# > 15869                                                 'The error occuring is:', e)
#   15870
#
# D:\anaconda3\envs\PT37\lib\site-packages\PySimpleGUI\PySimpleGUI.py in _error_popup_with_traceback(title, *args)
#   20930     line_num = error_parts[1][error_parts[1].index('line ') + 5:]
# > 20931     _error_popup_with_code(title, filename, line_num, error_message, *args)
#   20932
#
# D:\anaconda3\envs\PT37\lib\site-packages\PySimpleGUI\PySimpleGUI.py in _error_popup_with_code(title, filename, line_num, *args)
#   20955             popup_quick_message('KILLING APP!  BYE!', font='_ 18', keep_on_top=True, text_color='white', background_color='red', non_blocking=False)
# > 20956             sys.exit()
#   20957         if event == 'Take me to error' and filename is not None and line_num is not None:
#
# SystemExit:
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# D:\anaconda3\envs\PT37\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2091                            'the full traceback.\n']
#    2092                     stb.extend(self.InteractiveTB.get_exception_only(etype,
# -> 2093                                                                      value))
#    2094                 else:
#    2095                     try:
#
# D:\anaconda3\envs\PT37\lib\site-packages\IPython\core\ultratb.py in get_exception_only(self, etype, value)
#     752         value : exception value
#     753         """
# --> 754         return ListTB.structured_traceback(self, etype, value)
#     755
#     756     def show_exception_only(self, etype, evalue):
#
# D:\anaconda3\envs\PT37\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     631                     chained_exceptions_tb_offset, context)
#     632                 + chained_exception_message
# --> 633                 + out_list)
#     634
#     635         return out_list
#
# D:\anaconda3\envs\PT37\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1366             self.tb = tb
#    1367         return FormattedTB.structured_traceback(
# -> 1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#    1370
#
# D:\anaconda3\envs\PT37\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1266             # Verbose modes need a full traceback
#    1267             return VerboseTB.structured_traceback(
# -> 1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#    1270         elif mode == 'Minimal':
#
# D:\anaconda3\envs\PT37\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1123
#    1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1125                                                                tb_offset)
#    1126
#    1127         colors = self.Colors  # just a shorthand + quicker name lookup
#
# D:\anaconda3\envs\PT37\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# D:\anaconda3\envs\PT37\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()
